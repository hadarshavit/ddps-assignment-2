# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
ths = np.zeros((20, 120))

# %%
for i in range(20):
    try:
        d = np.load(f'results_fault/experiment_{i}.npy', allow_pickle=True)
    except:
        print(i)
        continue
    start_time = d[0][1]
    for res, time in d:
        real_time = time - start_time
        ths[i, round(real_time / 5)] += 1

# %%
all = []
for rep in range(20):
    for time in range(18):
        all.append((time * 5, ths[rep, time]))

# %%
df = pd.DataFrame(all, columns=['time', 'th'])

# %%
sns.lineplot(data=df, x='time', y='th')
plt.xlabel('Time (s)')
plt.ylabel('Throughput (configs / 5s)')
plt.savefig('figures/fault_tol.png')
plt.savefig('figures/fault_tol.pdf')
